# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos=np.loadtxt('circulos.dat')

# %%
x = datos[:,0]
y = datos[:,1]
fig = plt.figure(figsize=(8,8))
scatter(x, y, s=0.1)
xlim([-3.1, 3.1])
ylim([-3.1, 3.1])
# Out:
# (-3.1, 3.1)

# %%
pix = 256 
matriz=zeros((pix,pix))
espaciador= 6.0/pix


   

limiteX1=min(x)


    


for i in range(pix): 
    x1=limiteX1+(espaciador*contadorX)
    x2=limiteX1+(espaciador)
    limiteY1=min(y)
    
    for j in range(pix):
        y1=limiteY1+(espaciador*(j))
        y2=limiteY1+(espaciador)
        inds = where((x>=limiteX1) & (x<x2) & (y>=limiteY1) & (y<y2))
        if(len(inds[0]) != 0):
            matriz[(i,j)] = 1.0
        limiteY1 += espaciador
    limiteX1 += espaciador

# %%
fig=figure(figsize=(8,8))
imshow(matriz)
