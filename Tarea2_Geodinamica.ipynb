# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %% [markdown]
# Punto 2: alculando las graficas de topograf'ia, espesor y calor.

# %%
import matplotlib.pyplot as pltimport numpy as npfrom numpy import pi

# %%
n = 2.32k = 31.53 #m^2/yr (k = 1mm^2/s = 31.53 m^2/yr)u = 0.1905 #m/yrx = np.arange(0, 3256650.0, 1) #distance in the 30 latitude from the ridge to the trenchsq = ((k*x)/u)**0.5yl = (n*sq)print x
# Out:
# [  0.00000000e+00   1.00000000e+00   2.00000000e+00 ...,   3.25664700e+06   3.25664800e+06   3.25664900e+06]

# %%
plt.plot(x, yl)plt.xlabel('distance[m]')plt.ylabel('Thickness of the oceanic lithosphere [m]')#xlim([0, 3256650])

# %% [markdown]
# Now for the topography of the plate in this line

# %% [markdown]
# T = T1 - T0

# %%
T = 1250.0 #KELVINRhom = 3300.0 #Kg/m^Rhow = 1020.0 #Kg/m^3alfa = 0.00005 #K^-1rho = Rhom - Rhowt1 = T/rhosd = ((k*x)/(u*np.pi))**0.5Hy = t1 *alfa*Rhom*2*sdprint Hy
# Out:
# [  0.00000000e+00   1.31319332e+00   1.85713580e+00 ...,   2.36981262e+03   2.36981298e+03   2.36981335e+03]

# %%
plt.plot(x, -Hy)plt.xlabel('distance[m]')plt.ylabel('Topography of the oceanic lithosphere [m]')xlim([0, 3256650])
# Out:
# (0, 3256650)

# %% [markdown]
# Now for the Heat Flux

# %%
d1 = (u/(np.pi*k*x))**0.5q = 3.3*T*d1

# %%
plt.plot(x, q)plt.xlabel('distance[m]')plt.ylabel('Heat flux of the oceanic lithosphere ')xlim([0, 320])
# Out:
# (0, 320)
